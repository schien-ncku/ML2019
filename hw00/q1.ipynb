# %%
open('hw0_data.dat')
# Out:
# <_io.TextIOWrapper name='hw0_data.dat' mode='r' encoding='UTF-8'>

# %%
f = open('hw0_data.dat')
s = f.readline()
print(s)
# Out:
#  4.115 5.020 -7.879 -11.780 2.004 -0.353 -0.735 3.561 2.441 -9.822 +1

# %%
s = f.readline()
print(s)
# Out:
#  -3.557 0.997 2.932 7.672 5.430 -0.137 1.635 -5.190 -0.394 -7.667 +1

# %%
print(s[10])
# Out:
# 9

# %%
s.split()
print(s)
# Out:
#  -3.557 0.997 2.932 7.672 5.430 -0.137 1.635 -5.190 -0.394 -7.667 +1

# %%
n = s.split()
print(n)
# Out:
# ['-3.557', '0.997', '2.932', '7.672', '5.430', '-0.137', '1.635', '-5.190', '-0.394', '-7.667', '+1']

# %%
m = int(n)
print(m)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-f5dfdeafa679> in <module>
# ----> 1 m = int(n)
#       2 print(m)
#
# TypeError: int() argument must be a string, a bytes-like object or a number, not 'list'

# %%
m = []
for item in n:
    m.append(float(item))
    
print(m)
# Out:
# [-3.557, 0.997, 2.932, 7.672, 5.43, -0.137, 1.635, -5.19, -0.394, -7.667, 1.0]

# %%
n.sort()
print(n)
# Out:
# ['+1', '-0.137', '-0.394', '-3.557', '-5.190', '-7.667', '0.997', '1.635', '2.932', '5.430', '7.672']

# %%
m.sort()

# %%
print(m)
# Out:
# [-7.667, -5.19, -3.557, -0.394, -0.137, 0.997, 1.0, 1.635, 2.932, 5.43, 7.672]

# %%
answers = []
target = 1
with open('hw0_data.dat') as f:
    for line in f:
        n = line.split()
        answers.append(float(n[target]))
        
print(answers)
print(sorted(answers))
#answers.sort()
print(answers)
# Out:
# [5.02, 0.997, 5.878, 6.532, 5.834, 1.96, -6.797, -7.01, 4.813, -0.448, 3.801, 4.874, -4.978, -5.283, 5.177, 5.88, -5.006, -4.961, -1.866, -1.143, -0.54, -1.523, 3.835, 5.133, -2.113, 4.734, -0.915, 6.167, -9.453, 6.115, 0.542, 2.397, -1.605, 6.91, 0.246, 0.639, 5.931, 2.599, -5.484, 6.167, 5.218, 2.619, 6.571, 6.938, 6.9, 7.431, 1.819, -1.118, 4.14, 5.18, 0.729, 5.178, -0.026, -5.369, 5.231, -1.18, -8.588, -1.45, -0.119, 5.909, 6.175, -2.324, 6.812, -6.336, 5.431, 5.357, 5.439, -6.321, 5.604, -1.728, 4.353, 4.288, 1.338, 5.196, -4.977, -0.487, 6.222, 0.852, -0.32, 7.61, 3.505, -1.596, -1.456, -7.252, 2.337, 3.374, 2.171, 0.232, 4.938, -4.961, -0.285, -6.682, 7.745, 6.441, 5.905, -6.134, -1.124, -0.15, 5.701, 5.482, 0.388, 6.384, 6.444, -0.834, 5.956, 5.4, 2.099, 6.415, 6.23, -5.987, 5.672, -0.051, -1.071, 1.554, 0.615, -5.611, 1.042, -8.169, 6.541, 1.145, 5.42, -2.237, 6.508, 2.341, -1.619, -8.291, 6.428, -0.723, 5.609, 1.811, 3.986, -2.079, 0.769, 4.958, 5.773, 2.526, 5.779, 0.114, 
# ...
